# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print(2+2)
# Out:
# 4

# %%
jar1 = "peppers"
print(jar1)
# Out:
# peppers

# %%
type(jar1)
# Out:
# str

# %%
jar1 = "sugar"

# %%
#for loop demo
a_list = [6.49, 2.49, 8.98, 2.0, 0.4900000000000002, 20.160100000000003]
new_list=[]
print(new_list)
for obj in a_list:
    print(obj)
    new_list.append(2*obj)
    print(new_list)
print(a_list)
# Out:
# []
# 6.49
# [12.98]
# 2.49
# [12.98, 4.98]
# 8.98
# [12.98, 4.98, 17.96]
# 2.0
# [12.98, 4.98, 17.96, 4.0]
# 0.4900000000000002
# [12.98, 4.98, 17.96, 4.0, 0.9800000000000004]
# 20.160100000000003
# [12.98, 4.98, 17.96, 4.0, 0.9800000000000004, 40.32020000000001]
# [6.49, 2.49, 8.98, 2.0, 0.4900000000000002, 20.160100000000003]

# %%
#Conditional Statements
#comparison
x = 3 #assignment operation 
if x == 5:
    print("Value is equal to 5")
#else if = elif 
elif x < 5: 
    print("Value is less than 5")
else:
    print("Value is greater than 5")
# Out:
# Value is less than 5

# %%
#combining for loops and if else conditional statements 
num_list = [2,3,47,9,4,7,8,10,1,6,5]
y = 5
for num in num_list:
    if num == y:
        print(f"{num} is equal to {y}")
    elif num < y: 
        print(f":{num} is less than {y}")
    else: 
        print(f"{num} is greater than {y}")
# Out:
# :2 is less than 5
# :3 is less than 5
# 47 is greater than 5
# 9 is greater than 5
# :4 is less than 5
# 7 is greater than 5
# 8 is greater than 5
# 10 is greater than 5
# :1 is less than 5
# 6 is greater than 5
# 5 is equal to 5

# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %%
def cheerup():
    print("Good morning")
cheerup()
# Out:
# Good morning

# %%
def cheerup():
    #prints a greeting 
    print("Good Morning")
cheerup()
# Out:
# Good Morning

# %%
#Add a docstring
def cheerup(name = "Tigers"):
    #prints a greeting
    '''prints a greeting for the user'''
    print("Good morning")
cheerup?
# Out:
# Signature: cheerup(name='Tigers')
# Docstring: prints a greeting for the user
# File:      /var/folders/fy/2pg7d1sd6lq7gc_hwfspg70nvr_swx/T/ipykernel_31075/761903307.py
# Type:      function

# %%
#Passing arguments
def cheerup(name):
    print(f"Good Morning {name}!!")
cheerup("Monty")
cheerup()
# Out:
# Good Morning Monty!!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 5
#       3     print(f"Good Morning {name}!!")
#       4 cheerup("Monty")
# ----> 5 cheerup()
#
# TypeError: cheerup() missing 1 required positional argument: 'name'

# %%
#adding default argument
def cheerup(name = "tigers"):
    print(f"Good Morning {name}")
cheerup()
cheerup("Monty")
cheerup(3.14)
# Out:
# Good Morning tigers
# Good Morning Monty
# Good Morning 3.14
